# %%
import re  # For preprocessing
import pandas as pd  # For data handling
from time import time  # To time our operations
from collections import defaultdict  # For word frequency

import spacy  # For preprocessing

# %%
filename = "./input/bbt/datasetTBBT.csv"
f = open(filename, "r")  
corpus = f.readlines()
corpus = [ line.rstrip("\n") for line in corpus]

# %%
print(len(corpus))
# Out:
# 51515

# %%
#limpieza del dataset 
#para eso usamos spacy 
"""
Free open-source library for NLP.
It features NER, POS tagging, dependency parsing, word vectors and more.
"""
# descargar el paquete en inglés ----> python -m spacy  download en
nlp = spacy.load('en', disable=['ner', 'parser']) # se desabilita ner y parser

# %%
# removemos caracteres no alfabeticos 
#creamos un generador que va  a sustituir caracter no alfabeticos con espacios

def replace_chars( data, pattern, replacement):
    text = []
    for row in data:
        row = re.sub(pattern, replacement, str(row)).lower()
        text.append(row)
    return text

pattern = "[^A-Za-z’]+"
replacement = " "
text_only_alpha = replace_chars(corpus, pattern, replacement)
print(text_only_alpha)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#crear objetos tipo doc de spacy usando un generador
    #spicy funciona ve a los textos como  streams  enviandolos por tuberias(pipes)
docs_gen = nlp.pipe(text_only_alpha, batch_size=5000, n_threads=-1)

#los pasamos a una lista
sp_docs = [] 
for sp_doc in docs_gen:
    sp_docs.append(sp_doc)

# %%
#removemos stop words y lemmatizamos
def remove_stop_words_lemmatize(sp_docs):
    clean_docs = []
    for doc in sp_docs:
        clean_doc = []
        for token in doc:
            if not token.is_stop:
                clean_doc.append(token.lemma_ )
        if len(clean_doc) > 2: #los textos con solo dos tokens no valen la pena
            clean_docs.append( ' '.join(clean_doc) ) 
    return clean_docs

clean_docs = remove_stop_words_lemmatize(sp_docs)
print(clean_docs)
# Out:
# ['yeah uh look scientifically impossible person tip cow stocky build lumberjack shoulder', 'horrible push cow sacred', 'oh stop see eat like million hamburger', 'hey animal sacred delicious', 'look tell okay clearly remember cow stand cow', 'howard cow tip real', 'mmm go to base try roll mom snore speak big beef uh invite thanksgiving house', 'mmm know tell bald refusal invitation rude instead offer polite excuse love unfortunately sound awful', 'uh actually go to', 'bernadette bring dad because mom town guy', 'oh way love sound awful', 'actually nice hear sheldon complain cooking day', 'uh excuse year prepare terrible meal year criticize tradition mean', 'ugh fine food delicious thanksgiving ruin', 'mrs wolowitz house', 'expect good behaviour', 'know african slave feel drag home labour yoke white man', 'honestly compare thanksgiving dinner wolowitz mom great tragedy history mankind', 'sheldon nice thanksgiving spend vegas', 'yeah date zack actually fun think gamble go cheesy wedding chapel good turkey dinner surprising strip club', 'wait go chapel', 'silly fake wedding', 'penny know real right', 'let ask question point las vegas', 'mrs wolowitz house', 'oh bring beer everybody', 'uh okay yeah everybody want nice quiet day home watch game', 'quiet day watch game', 'howard medicine work', 'take let reach stomach hey mike let help', 'thank wrong mom', 'oh gout flare turn apple pie day doctor away', 'little toe hurt bad', 'maybe little piggy crush barn quiet soon give pain med choke', 'guess go to cooking', 'think go to crazy', 'go to raj', 'oh great idea', 'yes like ship come africa america', 'sheldon completely inappropriate compare slave', 'yes miss amy', 'believe married idiot', 'ugh stop goof', 'goof actually married need take care', 'make big deal', 'oh oh oh reason say yes marry zack time leonard propose get resounding yeah head', 'hope annulment like happen', 'say annulment follow condition meet unable consummate marriage', 'evidence fraud bigamy want understanding', 'want understand mean', 'ding ding ding winner', 'mrs wolowitz kitchen', 'thank save day', 'ah problem thanksgive indian provide food uh mom crisco', 'um know probably wad cheek', 'help raj dad company', 'want creepy little guy sex daughter', 'okay care lot', 'wife arizona grandkids', 'know mom arizona ride mule grand canyon long story short shoot cause fat door finish laugh hey guy', 'smell wonderful slave away kitchen know', 'oh mad find married zack', 'dumb ass date hysterical', 'believe feel bad open car', 'uh yeah uh reach uh gravy boat', 'great make okay lot time bernadette corn gravy yam detail amy roll cranberry make sure bernadette stay away marshmallow right okay question baste ass focus key', 'guy know penny marry zack year ago', 'tackle hallway school cheer', 'okay find uh court paper zack need fill print home', 'look screw go to talk rest day', 'mad stupid thing try fix', 'ugh need air', 'know thing woman follow', 'bad guy marry victim', 'sound like zack victim sleep wife', 'keep marriage year weigh', 'try watch game shut oh', 'pass nickel defence run tackle', 'father love football watch allow homework', 'happy know speak zack willing sign court paper way', 'get ready weigh', 'throw quick slant wideout give defence show blitz', 'oh love good blitz especially sour cream cause sound like blintz', 'understand invite today', 'shut call think', 'hey guy try cook', 'speak use blender want miss', 'cook invite zack', 'plot like gravy thickens', 'care mother bathroom angle business clown figurine stare', 'yeah remember thanksgiving game snow dallas', '  leon lett blow game final second dolphin emerge victorious finally get calculus', 'pissed want shoot tv', 'dad live texas', 'man own local liquor store cry cry', 'oh thanks dad die old beer man', 'sir try high school graduation mom say', 'mind have moment', 'believe penny marry zack', 'wonder see guy', 'know sweet tall handsome', 'broad shoulder good hair', 'hmm wonder see leonard', 'sheldon dad bond compl ...

# %%
from gensim.models.phrases import Phrases, Phraser
sent = [row.split() for row in clean_docs]


print(sent)

phrases = Phrases(sent, min_count=30, progress_per=10000)

bigram = Phraser(phrases)
sentences = bigram[sent]
# Out:
# [['yeah', 'uh', 'look', 'scientifically', 'impossible', 'person', 'tip', 'cow', 'stocky', 'build', 'lumberjack', 'shoulder'], ['horrible', 'push', 'cow', 'sacred'], ['oh', 'stop', 'see', 'eat', 'like', 'million', 'hamburger'], ['hey', 'animal', 'sacred', 'delicious'], ['look', 'tell', 'okay', 'clearly', 'remember', 'cow', 'stand', 'cow'], ['howard', 'cow', 'tip', 'real'], ['mmm', 'go', 'to', 'base', 'try', 'roll', 'mom', 'snore', 'speak', 'big', 'beef', 'uh', 'invite', 'thanksgiving', 'house'], ['mmm', 'know', 'tell', 'bald', 'refusal', 'invitation', 'rude', 'instead', 'offer', 'polite', 'excuse', 'love', 'unfortunately', 'sound', 'awful'], ['uh', 'actually', 'go', 'to'], ['bernadette', 'bring', 'dad', 'because', 'mom', 'town', 'guy'], ['oh', 'way', 'love', 'sound', 'awful'], ['actually', 'nice', 'hear', 'sheldon', 'complain', 'cooking', 'day'], ['uh', 'excuse', 'year', 'prepare', 'terrible', 'meal', 'year', 'criticize', 'tradition', 'mean'], ['ugh', 'fine', 'food', 'delicious', 'thanksgiving', 'ruin'], ['mrs', 'wolowitz', 'house'], ['expect', 'good', 'behaviour'], ['know', 'african', 'slave', 'feel', 'drag', 'home', 'labour', 'yoke', 'white', 'man'], ['honestly', 'compare', 'thanksgiving', 'dinner', 'wolowitz', 'mom', 'great', 'tragedy', 'history', 'mankind'], ['sheldon', 'nice', 'thanksgiving', 'spend', 'vegas'], ['yeah', 'date', 'zack', 'actually', 'fun', 'think', 'gamble', 'go', 'cheesy', 'wedding', 'chapel', 'good', 'turkey', 'dinner', 'surprising', 'strip', 'club'], ['wait', 'go', 'chapel'], ['silly', 'fake', 'wedding'], ['penny', 'know', 'real', 'right'], ['let', 'ask', 'question', 'point', 'las', 'vegas'], ['mrs', 'wolowitz', 'house'], ['oh', 'bring', 'beer', 'everybody'], ['uh', 'okay', 'yeah', 'everybody', 'want', 'nice', 'quiet', 'day', 'home', 'watch', 'game'], ['quiet', 'day', 'watch', 'game'], ['howard', 'medicine', 'work'], ['take', 'let', 'reach', 'stomach', 'hey', 'mike', 'let', 'help'], ['thank', 'wrong', 'mom'], ['oh', 'gout', 'flare', 'turn', 'apple', 'pie', 'day', 'doctor', 'away'], ['little', 'toe', 'hurt', 'bad'], ['maybe', 'little', 'piggy', 'crush', 'barn', 'quiet', 'soon', 'give', 'pain', 'med', 'choke'], ['guess', 'go', 'to', 'cooking'], ['think', 'go', 'to', 'crazy'], ['go', 'to', 'raj'], ['oh', 'great', 'idea'], ['yes', 'like', 'ship', 'come', 'africa', 'america'], ['sheldon', 'completely', 'inappropriate', 'compare', 'slave'], ['yes', 'miss', 'amy'], ['believe', 'married', 'idiot'], ['ugh', 'stop', 'goof'], ['goof', 'actually', 'married', 'need', 'take', 'care'], ['make', 'big', 'deal'], ['oh', 'oh', 'oh', 'reason', 'say', 'yes', 'marry', 'zack', 'time', 'leonard', 'propose', 'get', 'resounding', 'yeah', 'head'], ['hope', 'annulment', 'like', 'happen'], ['say', 'annulment', 'follow', 'condition', 'meet', 'unable', 'consummate', 'marriage'], ['evidence', 'fraud', 'bigamy', 'want', 'understanding'], ['want', 'understand', 'mean'], ['ding', 'ding', 'ding', 'winner'], ['mrs', 'wolowitz', 'kitchen'], ['thank', 'save', 'day'], ['ah', 'problem', 'thanksgive', 'indian', 'provide', 'food', 'uh', 'mom', 'crisco'], ['um', 'know', 'probably', 'wad', 'cheek'], ['help', 'raj', 'dad', 'company'], ['want', 'creepy', 'little', 'guy', 'sex', 'daughter'], ['okay', 'care', 'lot'], ['wife', 'arizona', 'grandkids'], ['know', 'mom', 'arizona', 'ride', 'mule', 'grand', 'canyon', 'long', 'story', 'short', 'shoot', 'cause', 'fat', 'door', 'finish', 'laugh', 'hey', 'guy'], ['smell', 'wonderful', 'slave', 'away', 'kitchen', 'know'], ['oh', 'mad', 'find', 'married', 'zack'], ['dumb', 'ass', 'date', 'hysterical'], ['believe', 'feel', 'bad', 'open', 'car'], ['uh', 'yeah', 'uh', 'reach', 'uh', 'gravy', 'boat'], ['great', 'make', 'okay', 'lot', 'time', 'bernadette', 'corn', 'gravy', 'yam', 'detail', 'amy', 'roll', 'cranberry', 'make', 'sure', 'bernadette', 'stay', 'away', 'marshmallow', 'right', 'okay', 'question', 'baste', 'ass', 'focus', 'key'], ['guy', 'know', 'penny', 'marry', 'zack', 'year', 'ago'], ['tackle', 'hallway', 'sc ...

# %%
import multiprocessing

from gensim.models import Word2Vec
cores = multiprocessing.cpu_count() # Count the number of cores in a computer


w2v_model = Word2Vec(min_count=20,
                     window=2,
                     size=300,
                     sample=6e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20,
                     workers=cores-1)

# %%
w2v_model.build_vocab(sentences, progress_per=10000)
print(w2v_model)
# Out:
# Word2Vec(vocab=1504, size=300, alpha=0.03)

# %%
w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=30, report_delay=1)
# Out:
# (1610263, 6208770)

# %%
w2v_model.save("word2vec_tbt.model")

# %%
print( w2v_model.wv.similarity("leonard", 'sheldon') ) 
print( w2v_model.wv.similarity("black", 'white') ) 
print( w2v_model.wv.similarity("penny", 'bernadette') ) 
print( w2v_model.wv.similarity("geology", 'physics') )
# Out:
# 0.9793476
# 0.9879356
# 0.91158354
# 0.96623874
